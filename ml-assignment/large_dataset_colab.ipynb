# %%
# !git clone https://github.com/Priya-96-aiml/ml-intern-assessment.git
# Out:
# Cloning into 'ml-intern-assessment'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 30 (delta 6), reused 0 (delta 0), pack-reused 14 (from 1)
# Receiving objects: 100% (30/30), 8.09 KiB | 2.70 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
import sys
sys.path.append('/content/ml-intern-assessment/ml-assignment/src')

from ngram_model import TrigramModel
from utils import clean_text, tokenize

file_path = "/content/ml-intern-assessment/ml-assignment/data/example_corpus.txt"

with open(file_path, "r") as f:
    corpus = f.read()

print("Corpus Loaded:")
print(corpus)

model = TrigramModel()
model.fit(corpus)

generated_text = model.generate(max_length=30)
print("\nGenerated Text:\n", generated_text)
# Out:
# Corpus Loaded:
# This is an example corpus for the trigram assignment.
# It contains a few sentences to get you started.
# You can use this corpus to train and test your trigram model.
# Feel free to add more text to this file or use your own corpus.
# The more data you have, the better your model will be.
# Good luck!
#
#
# Generated Text:
#  this is an example corpus for the trigram assignment it contains a few sentences to get you started you can use this corpus to train and test your trigram model

# %%
# !wget -O alice.txt https://www.gutenberg.org/files/11/11-0.txt
# Out:
# --2025-11-20 16:36:03--  https://www.gutenberg.org/files/11/11-0.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 151191 (148K) [text/plain]
# Saving to: ‘alice.txt’
#
# alice.txt           100%[===================>] 147.65K   231KB/s    in 0.6s
#
# 2025-11-20 16:36:05 (231 KB/s) - ‘alice.txt’ saved [151191/151191]

# %%
file_path = "alice.txt"  # replace with your large text file

# %%
import sys
sys.path.append('/content/ml-intern-assessment/ml-assignment/src')

from ngram_model import TrigramModel
from utils import clean_text, tokenize

# Load large corpus
with open(file_path, "r", encoding="utf-8") as f:
    corpus = f.read()

print("Corpus Loaded. Length:", len(corpus), "characters")

# Train model
model = TrigramModel()
model.fit(corpus)
print("Model trained successfully.")

# Generate new text
generated_text = model.generate(max_length=100)  # can increase to 200+ for larger outputs
print("\nGenerated Text:\n", generated_text)
# Out:
# Corpus Loaded. Length: 144696 characters
# Model trained successfully.
#
# Generated Text:
#  start of the mushroom and raised herself to see the earth let me see that queer little toss of her own mind as well as she fell past it well thought alice as he spoke and the executioner ran wildly up and straightening itself out again the duchess digging her sharp little chin ive a right to grow up again dear i wish you could only see her after the birds why shell eat a little while however she again heard a voice she had never before seen a rabbit i suppose i ought to tell its age there was
